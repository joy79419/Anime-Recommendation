# %%
import pandas as pd

df = pd.read_csv('animelists_cleaned.csv')
df[:5]
# Out:
#    username  anime_id  my_watched_episodes my_start_date my_finish_date  \
# 0  karthiga        21                  586    0000-00-00     0000-00-00
# 1  karthiga        59                   26    0000-00-00     0000-00-00
# 2  karthiga        74                   26    0000-00-00     0000-00-00
# 3  karthiga       120                   26    0000-00-00     0000-00-00
# 4  karthiga       178                   26    0000-00-00     0000-00-00
#
#    my_score  my_status  my_rewatching  my_rewatching_ep      my_last_updated  \
# 0         9          1            NaN                 0  2013-03-03 10:52:53
# 1         7          2            NaN                 0  2013-03-10 13:54:51
# 2         7          2            NaN                 0  2013-04-27 16:43:35
# 3         7          2            NaN                 0  2013-03-03 10:53:57
# 4         7          2            0.0                 0  2013-03-27 15:59:13
#
#   my_tags
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
#data = df[['username','anime_id','my_score','my_last_updated']]
#data.to_csv('data.csv',index=False)

# %%
data = pd.read_csv('data.csv')
data["my_score"].describe()
# Out:
# count    3.128403e+07
# mean     4.652315e+00
# std      3.931615e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      6.000000e+00
# 75%      8.000000e+00
# max      1.000000e+01
# Name: my_score, dtype: float64

# %%
from surprise import SVD
from surprise.model_selection import cross_validate
from surprise import Reader
from surprise import Dataset
from surprise.model_selection import train_test_split
from surprise import accuracy

reader = Reader(rating_scale=(0, 10))

data1 = Dataset.load_from_df(data[['username', 'anime_id', 'my_score']], reader)
trainset, testset = train_test_split(data1, test_size=.25)
algo = SVD()
algo.fit(trainset)
predictions = algo.fit(trainset).test(testset)
accuracy.rmse(predictions)

#cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# RMSE: 3.1317
# 3.1316942265902195

# %%
predictions
# Out:
# [Prediction(uid='Aviv-san', iid=2891, r_ui=6.0, est=5.837492295452124, details={'was_impossible': False}),
#  Prediction(uid='AndyAndain', iid=18897, r_ui=9.0, est=6.356052449628184, details={'was_impossible': False}),
#  Prediction(uid='Tiberias', iid=1840, r_ui=8.0, est=8.409529306756273, details={'was_impossible': False}),
#  Prediction(uid='briii', iid=29317, r_ui=8.0, est=6.737830820279523, details={'was_impossible': False}),
#  Prediction(uid='karuro-kun', iid=2167, r_ui=9.0, est=7.763652080720686, details={'was_impossible': False}),
#  Prediction(uid='Equez', iid=19151, r_ui=0.0, est=4.385949298347243, details={'was_impossible': False}),
#  Prediction(uid='Apolo_Levitt', iid=2025, r_ui=0.0, est=0, details={'was_impossible': False}),
#  Prediction(uid='Mikii', iid=8408, r_ui=8.0, est=8.835153224597505, details={'was_impossible': False}),
#  Prediction(uid='LynBhelliom', iid=6351, r_ui=7.0, est=4.178176912220257, details={'was_impossible': False}),
# ...
